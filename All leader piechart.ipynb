# %%
import pandas as pd

# %%
import nltk
import scipy as sc
# %matplotlib inline
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
import googletrans
from googletrans import *
translator=googletrans.Translator()

# %%
df=pd.read_csv("C:\\Users\\Shubham\\Desktop\\Leader Merge File.csv")

# %%
Amit_Shah_negative=df[(df['score']=='Positive') & (df['leader']=='amit')]
print(str(Amit_Shah_negative.shape[0]/(df.shape[0])*100)+'% of Negative tweets')
Amit_Shah_negative=Amit_Shah_negative.shape[0]/df.shape[0]*100
# Out:
# 7.661331804888086% of Negative tweets

# %%
Narendra_Modi_negative=df[(df['score']=='Positive') & (df['leader']=='Narendra Modi')]
print(str(Narendra_Modi_negative.shape[0]/(df.shape[0])*100)+'% of Negative tweets')
Narendra_Modi_negative=Narendra_Modi_negative.shape[0]/df.shape[0]*100
# Out:
# 5.597930720279823% of Negative tweets

# %%
Arvind_Kejriwal_negative=df[(df['score']=='Positive') & (df['leader']=='Arvind Kejriwal')]
print(str(Arvind_Kejriwal_negative.shape[0]/(df.shape[0])*100)+'% of Negative tweets')
Arvind_Kejriwal_negative=Arvind_Kejriwal_negative.shape[0]/df.shape[0]*100
# Out:
# 6.579662860250137% of Negative tweets

# %%
Mamata_Banerjee_negative=df[(df['score']=='Positive') & (df['leader']=='Mamata Banerjee')]
print(str(Mamata_Banerjee_negative.shape[0]/(df.shape[0])*100)+'% of Negative tweets')
Mamata_Banerjee_negative=Mamata_Banerjee_negative.shape[0]/df.shape[0]*100
# Out:
# 2.9033111414840618% of Negative tweets

# %%
Rahul_Gandhi_negative=df[(df['score']=='Positive') & (df['leader']=='Rahul Gandhi')]
print(str(Rahul_Gandhi_negative.shape[0]/(df.shape[0])*100)+'% of Negative tweets')
Rahul_Gandhi_negative=Rahul_Gandhi_negative.shape[0]/df.shape[0]*100
# Out:
# 7.583439883603016% of Negative tweets

# %%
Rajnath_Singh_negative=df[(df['score']=='Positive') & (df['leader']=='rajnath')]
print(str(Rajnath_Singh_negative.shape[0]/(df.shape[0])*100)+'% of Negative tweets')
Rajnath_Singh_negative=Rajnath_Singh_negative.shape[0]/df.shape[0]*100
# Out:
# 3.619035021971401% of Negative tweets

# %%
yogi_negative=df[(df['score']=='Positive') & (df['leader']=='yogi')]
print(str(yogi_negative.shape[0]/(df.shape[0])*100)+'% of Negative tweets')
yogi_negative=yogi_negative.shape[0]/df.shape[0]*100
# Out:
# 5.146010610937202% of Negative tweets

# %%
explode=(0,0,0,0,0,0,0)
labels = 'Narendra Modi', 'Amit Shah', 'Arvind Kejriwal', 'Mamata Banerjee', 'Rahul Gandhi', 'Rajnath Singh', 'yogi'
sizes = [Amit_Shah_negative, Narendra_Modi_negative, Arvind_Kejriwal_negative, Mamata_Banerjee_negative, Rahul_Gandhi_negative, Rajnath_Singh_negative, yogi_negative]
colors = ['Yellow', 'lightblue', 'grey',  'Green', 'Blue', 'Red', 'pink']

# %%
plt.pie(sizes,explode=explode, colors=colors,autopct='%1.lf%%')
plt.legend(labels, loc=(-0.5, 0.05), shadow=True)
plt.axis('equal')
plt.savefig('All.png')
